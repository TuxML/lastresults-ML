# %%
import pandas as pd
res = pd.read_csv("results.csv")
fti = pd.read_csv("feature_importance.csv")

# %%
res
# Out:
#      count       mean        std       min       25%        50%        75%  \
# 0  12355.0  12.601851  10.478911  0.000410  4.862241  10.124772  17.721257
# 1  12355.0   8.366907   7.680151  0.001318  2.939703   6.439926  11.461246
#
#           max criterion  max_depth  ...  max_features  random_state  \
# 0  109.273391       mse         10  ...          auto           NaN
# 1  102.813186       mse         25  ...          auto          None
#
#    max_leaf_nodes min_impurity_decrease min_impurity_split n_estimators  \
# 0             NaN          1.000000e-07                  0           50
# 1            None          1.000000e-07                  0           50
#
#    n_jobs  random_id  train_size  nb_yes
# 0      -1   0.112647     90000.0     1.0
# 1      -1   0.038798     90000.0     1.0
#
# [2 rows x 23 columns]

# %%
fti.iloc[0].sort_values(ascending=False) 
# fti.iloc[0].rank(ascending=False)['CC_OPTIMIZE_FOR_SIZE']
# fti.iloc[0].rank(ascending=False)['DEBUG_INFO']
# Out:
# DEBUG_INFO                   0.335291
# nbyes                        0.186925
# DEBUG_INFO_REDUCED           0.113501
# DEBUG_INFO_SPLIT             0.086415
# RANDOMIZE_BASE               0.077960
# X86_NEED_RELOCS              0.069135
# UBSAN_SANITIZE_ALL           0.035642
# KASAN                        0.008829
# KASAN_OUTLINE                0.008781
# UBSAN_ALIGNMENT              0.007302
# GCOV_PROFILE_ALL             0.006885
# nbyesmodule                  0.004272
# nbno                         0.003761
# XFS_DEBUG                    0.003077
# DRM_NOUVEAU                  0.001219
# XFS_FS                       0.000814
# KCOV_INSTRUMENT_ALL          0.000702
# UBSAN_NULL                   0.000674
# DRM_RADEON                   0.000601
# FDDI                         0.000518
# MAXSMP                       0.000475
# DRM_AMDGPU                   0.000442
# MISDN_W6692                  0.000430
# BLK_MQ_PCI                   0.000418
# ATH5K_TRACER                 0.000342
# SCSI_ISCSI_ATTRS             0.000317
# MDIO                         0.000251
# DRM_I915                     0.000248
# DRM_GMA500                   0.000244
# MMU_NOTIFIER                 0.000200
#                                ...
# ATM_ENI_BURST_RX_8W          0.000000
# FB_GEODE_GX                  0.000000
# FB_GEODE_LX                  0.000000
# ATM_ENI_BURST_RX_16W         0.000000
# SERIAL_SH_SCI                0.000000
# USB_MSM_OTG                  0.000000
# CRYPTO_ALGAPI2               0.000000
# I2C_BRCMSTB                  0.000000
# XEN_PCIDEV_BACKEND           0.000000
# DEVFREQ_EVENT_EXYNOS_NOCP    0.000000
# SND_SOC_AK4641               0.000000
# USB_GSPCA_FINEPIX            0.000000
# SND_SOC_UDA1380              0.000000
# KALLSYMS_BASE_RELATIVE       0.000000
# MV_XOR                       0.000000
# SND_SOC_AK4671               0.000000
# SND_SOC_WM8940               0.000000
# VIDEO_OV5693                 0.000000
# KALLSYMS                     0.000000
# MMP_TDMA                     0.000000
# REGULATOR_HI655X             0.000000
# MMP_PDMA                     0.000000
# PCIE_ROCKCHIP                0.000000
# SERIAL_SH_SCI_DMA            0.000000
# SND_SOC_AK4535               0.000000
# SERIAL_SH_SCI_EARLYCON       0.000000
# SND_SOC_ADS117X              0.000000
# K3_DMA                       0.000000
# USB_QCOM_8X16_PHY            0.000000
# VIDEO_ATOMISP                0.000000
# Name: 0, Length: 9239, dtype: float64
